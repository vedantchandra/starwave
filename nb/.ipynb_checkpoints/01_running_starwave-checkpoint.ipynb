# %%
import sys
sys.path.append('/Users/vedantchandra/0_research/software/starwave/')
import starwave

import numpy as np
import matplotlib.pyplot as plt
import bz2
import pandas as pd
from matplotlib.colors import LogNorm
import torch
from sbi import utils


plt.style.use('vedant')

# %% [markdown]
# ### Load Isochrones

# %%
with bz2.BZ2File('/Users/vedantchandra/0_research/02_starwave/DATA/LMC_2022/isolib_LMC_df_corr.pbz2') as f:
    isodf = pd.read_pickle(f)

# %%
len(isodf)
# Out:
# 6400177

# %%
# SWAP incorrect colors

# isodf['F160W_new'] = isodf['F110W']
# isodf['F110W'] = isodf['F160W']
# isodf['F160W'] = isodf['F160W_new']

# %%
idx = isodf.index[6361265]
#print(idx[1])
#idx = [-1.0, idx[1], None]

# %%
plt.scatter(isodf.loc[idx[:2]]['F110W'] - isodf.loc[idx[:2]]['F160W'], 
           isodf.loc[idx[:2]]['F110W'])

plt.gca().invert_yaxis()

#plt.xlim(0.3, 0.9)

# %%
#Rename to correct format

# isodf['F160W'] = isodf['F110W']
# isodf['F110W'] = isodf['F160W']

#already in good format

# %% [markdown]
# ### Load Artifical Stars

# %%
with bz2.BZ2File('/Users/vedantchandra/0_research/02_starwave/DATA/LMC_2022/AScat.pbz2') as f:
    asdf = pd.read_pickle(f)
asdf = pd.DataFrame(asdf)

# %%
# Rename to correct format, remove undetected stars

print(len(asdf))
detected = np.array(asdf['AS_det'])
asdf['F110W_in'] = asdf['AS_mag1_in']
asdf['F110W_out'] = asdf['AS_mag1_out']

asdf['F160W_in'] = asdf['AS_mag2_in']
asdf['F160W_out'] = asdf['AS_mag2_out']

asdf['F110W_out'].loc[~detected] = np.nan
asdf['F160W_out'].loc[~detected] = np.nan
# Out:
# 2400000
# /var/folders/6d/8w3sw49j3715htmfyjnsf0zh0000gn/T/ipykernel_96444/674033317.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asdf['F110W_out'].loc[~detected] = np.nan
# /var/folders/6d/8w3sw49j3715htmfyjnsf0zh0000gn/T/ipykernel_96444/674033317.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asdf['F160W_out'].loc[~detected] = np.nan

# %%
plt.hist2d(asdf['F110W_in'] - asdf['F160W_in'], asdf['F160W_in'],
          bins = 250, norm = LogNorm());

plt.gca().invert_yaxis()
plt.xlabel('$F110W - F160W$')
plt.ylabel('$F160W$')
# Out:
# Text(0, 0.5, '$F160W$')

# %%
plt.hist2d(asdf['F110W_out'] - asdf['F160W_out'], asdf['F160W_out'],
          bins = 250, norm = LogNorm(),
          range = ((-1.5, 0), (24, 30)));

plt.gca().invert_yaxis()
plt.xlabel('$F110W - F160W$')
plt.ylabel('$F160W$')
# Out:
# Text(0, 0.5, '$F160W$')

# %% [markdown]
# ### Load HST LMC Data

# %%
with bz2.BZ2File('/Users/vedantchandra/0_research/02_starwave/DATA/LMC_2022/catalog.pbz2') as f:
    lmc = pd.read_pickle(f)
lmc = pd.DataFrame(lmc)

lmc = lmc[lmc['dat_det']]

# %%
lmc['F110W'] = lmc['dat_mag1']
lmc['F160W'] = lmc['dat_mag2']

# %%
plt.scatter(lmc['F110W'] - lmc['F160W'], lmc['F160W'], s = 1, alpha = 0.5, color = 'k')

plt.gca().invert_yaxis()

plt.xlabel('$F110W - F160W$')
plt.ylabel('$F160W$')
# Out:
# Text(0, 0.5, '$F160W$')

# %%
shortbands = ['F160W', 'F110W']

# %% [markdown]
# ### Setup starwave

# %%
# sw = starwave.StarWave(isodf = isodf, asdf = asdf, imf_type = 'spl',
#                       bands = shortbands)

# %%
with bz2.BZ2File('/Users/vedantchandra/0_research/02_starwave/DATA/LMC_2022/SFH_2d_frommarginals_metalbound.pbz2') as f:
    sfh_grid = pd.read_pickle(f)

# %%
print(np.min(isodf.index.get_level_values('age')))

print(np.max(isodf.index.get_level_values('age')))
# Out:
# 0.5
# 15.815

# %%
print(sfh_grid['ages'].min())
# Out:
# 0.0

# %%
print(sfh_grid['ages'].max())
# Out:
# 13.4

# %%
sw = starwave.StarWave(isodf = isodf, asdf = asdf, imf_type = 'spl',
                      bands = shortbands, sfh_type = 'grid', sfh_grid = sfh_grid)
# Out:
# interpolating 224 ages and 16 metallicities...
# 224it [00:35,  6.39it/s]
# initalized starwave with ['F160W', 'F110W'] bands, spl IMF, and default priors
# ----------
# log_int
# ----------
# Distribution:  uniform
# Bounds:  [2, 6]
# Value:  2
# Fixed:  False
# dist_kwargs:  None
# ----------
# bf
# ----------
# Distribution:  uniform
# Bounds:  [0, 1]
# Value:  0.2
# Fixed:  False
# dist_kwargs:  None
# ----------
# dm
# ----------
# Distribution:  uniform
# Bounds:  [0, 1]
# Value:  0
# Fixed:  True
# dist_kwargs:  None
# ----------
# sig_dm
# ----------
# Distribution:  uniform
# Bounds:  [0, 0.5]
# Value:  0.1
# Fixed:  True
# dist_kwargs:  None
# ----------
# slope
# ----------
# Distribution:  uniform
# Bounds:  [-4, -1]
# Value:  -2.3
# Fixed:  False
# dist_kwargs:  None

# %%
logint = 4.8

sw.params['dm'].set(value = 18.52, fixed = True, bounds = [18, 19])
sw.params['log_int'].set(value = logint, bounds = (logint - .5, logint + .25))
sw.params['bf'].set(value = 0.4, fixed = True)

# %% [raw]
# sw.params['sig_age'].set(value = 0.1, fixed = True)
# sw.params['sig_feh'].set(value = 0.1, fixed = True)
# sw.params['sig_dm'].set(value = 0.01, fixed = True)
# sw.params['age_feh_corr'].set(value = 0, fixed = True)
#
# sw.params['age'].set(bounds = [9, 10.1], value = 10.1, fixed = True)
# sw.params['feh'].set(bounds = [-2.6, 0], value = -0.9, fixed = False)
#
# sw.make_prior(sw.params)

# %%
sw.params
# Out:
# SWParameters([('log_int',
#                SWParameter([('name', 'log_int'),
#                             ('value', 4.8),
#                             ('bounds', (4.3, 5.05)),
#                             ('distribution', 'uniform'),
#                             ('dist_kwargs', None),
#                             ('fixed', False)])),
#               ('bf',
#                SWParameter([('name', 'bf'),
#                             ('value', 0.4),
#                             ('bounds', [0, 1]),
#                             ('distribution', 'uniform'),
#                             ('dist_kwargs', None),
#                             ('fixed', True)])),
#               ('dm',
#                SWParameter([('name', 'dm'),
#                             ('value', 18.52),
#                             ('bounds', [18, 19]),
#                             ('distribution', 'uniform'),
#                             ('dist_kwargs', None),
#                             ('fixed', True)])),
#               ('sig_dm',
#                SWParameter([('name', 'sig_dm'),
#                             ('value', 0.1),
#                             ('bounds', [0, 0.5]),
#                             ('distribution', 'uniform'),
#                             ('dist_kwargs', None),
#                             ('fixed', True)])),
#               ('slope',
#                SWParameter([('name', 'slope'),
#                             ('value', -2.3),
#                             ('bounds', [-4, -1]),
#                             ('distribution', 'uniform'),
#                             ('dist_kwargs', None),
#                             ('fixed', False)]))])

# %%
# Plot LMC and sampled CMD

lmc_mags = np.vstack((lmc[shortbands[0]], lmc[shortbands[1]])).T
lmc_cmd = sw.make_cmd(lmc_mags)

params = torch.tensor([logint, -2.3])
eg_cmd = sw.sample_cmd(params, model = 'spl')[1]

starwave.plot_cmd(lmc_cmd, bands = shortbands)
starwave.plot_cmd(eg_cmd, bands = shortbands)

plt.gca().invert_yaxis()
# Out:
# intNN warning: age out of bounds

# %% [markdown]
# ### Run Starwave

# %%
posteriors = sw.fit_cmd(eg_cmd, cores = 1, n_sims = 100, n_rounds = 3, gamma = None, 
                       gamma_kw = dict(q = 0.68, NN = 5, fac = 1))
# Out:
# scaler initialized and mapping defined!
# finding optimal kernel width...
# setting gamma = 8968
# ----------
# log_int
# ----------
# Distribution:  uniform
# Bounds:  (4.3, 5.05)
# Value:  4.8
# Fixed:  False
# dist_kwargs:  None
# ----------
# bf
# ----------
# Distribution:  uniform
# Bounds:  [0, 1]
# Value:  0.4
# Fixed:  True
# dist_kwargs:  None
# ----------
# dm
# ----------
# Distribution:  uniform
# Bounds:  [18, 19]
# Value:  18.52
# Fixed:  True
# dist_kwargs:  None
# ----------
# sig_dm
# ----------
# Distribution:  uniform
# Bounds:  [0, 0.5]
# Value:  0.1
# Fixed:  True
# dist_kwargs:  None
# ----------
# slope
# ----------
# Distribution:  uniform
# Bounds:  [-4, -1]
# Value:  -2.3
# Fixed:  False
# dist_kwargs:  None
# Starting round 1 of neural inference...
# Running 100 simulations.:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
import sbi

# %% [raw]
# res = sbi.inference.infer(sw.simulator, sw.prior, method = 'SNPE', num_simulations = 100)

# %%
posterior = sw.posteriors[-1]

# %%
print(posterior)

# %%
posterior_samples = posterior.sample((1000000,), x = sw.obs)

# %%
from sbi.analysis import pairplot

# %%
_ = pairplot(posterior_samples, 
                   fig_size=(10,10))

# %%
import corner

# %%
f = corner.corner(np.array(posterior_samples), show_titles = True, 
                  labels = list(sw.param_mapper.keys()), title_kwargs = dict(fontsize = 14))
